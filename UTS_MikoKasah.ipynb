# %% [markdown]
# <a href="https://colab.research.google.com/github/bakasosay-cod/Mikokasah9/blob/main/UTS_MikoKasah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install google-play-scraper

# %%
from google_play_scraper import reviews, Sort
import csv

result, _ = reviews(
    'mlpt.siemo.mobilebankingbsb',
    lang='id',
    country='id',
    sort=Sort.NEWEST,
    count=1200,
    filter_score_with=None
)

filename = 'ulasan_google_play.csv'


with open(filename, 'w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=['userName', 'score', 'at', 'content'])
    writer.writeheader()
    for review in result:

        writer.writerow({
            'userName': review['userName'],
            'score': review['score'],
            'at': review['at'],
            'content': review['content']
        })

print(f"Berhasil menyimpan {len(result)} ulasan ke '{filename}'")
# Out:
# Berhasil menyimpan 1200 ulasan ke 'ulasan_google_play.csv'
